# %% [markdown]
# #Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("SampleSuperstore.csv")
data
# Out:
#            Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0       Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1       Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2       Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3     Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4     Standard Class   Consumer  United States  ...        2     0.20    2.5164
# ...              ...        ...            ...  ...      ...      ...       ...
# 9989    Second Class   Consumer  United States  ...        3     0.20    4.1028
# 9990  Standard Class   Consumer  United States  ...        2     0.00   15.6332
# 9991  Standard Class   Consumer  United States  ...        2     0.20   19.3932
# 9992  Standard Class   Consumer  United States  ...        4     0.00   13.3200
# 9993    Second Class   Consumer  United States  ...        2     0.00   72.9480
#
# ...

# %% [markdown]
# #Data preprocessing

# %%
data.shape
# Out:
# (9994, 13)

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
cor = data.corr()
cor
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
plt.figure(figsize=(12,6))
sns.heatmap(data = cor, annot = True)

# %% [markdown]
# #Data Visualization

# %%
data['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(data['Ship Mode'])
plt.xlabel("Ship Modes", fontsize = 15)
plt.ylabel("Count", fontsize = 15)
plt.title("Count of different Ship modes", fontsize = 20)
plt.xticks(fontsize = 15, rotation =45)
plt.yticks(fontsize = 15)
# Out:
# (array([   0., 1000., 2000., 3000., 4000., 5000., 6000., 7000.]),
#  <a list of 8 Text major ticklabel objects>)

# %%
data['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(data['Segment'])
plt.xlabel("Segment", fontsize = 15)
plt.ylabel("Count", fontsize = 15)
plt.title("Count of different segments", fontsize = 20)
plt.xticks(fontsize = 15, rotation =45)
plt.yticks(fontsize = 15)
# Out:
# (array([   0., 1000., 2000., 3000., 4000., 5000., 6000.]),
#  <a list of 7 Text major ticklabel objects>)

# %%
data['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(data['Category'])
plt.xlabel("Cateogry", fontsize = 15)
plt.ylabel("Count", fontsize = 15)
plt.title("Count of different categories", fontsize = 20)
plt.xticks(fontsize = 15, rotation =45)
plt.yticks(fontsize = 15)
# Out:
# (array([   0., 1000., 2000., 3000., 4000., 5000., 6000., 7000.]),
#  <a list of 8 Text major ticklabel objects>)

# %%
data['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.countplot(data['Sub-Category'])
plt.xlabel("Sub Cateogry", fontsize = 15)
plt.ylabel("Count", fontsize = 15)
plt.title("Count of different sub categories", fontsize = 20)
plt.xticks(fontsize = 15, rotation =45)
plt.yticks(fontsize = 15)
# Out:
# (array([   0.,  200.,  400.,  600.,  800., 1000., 1200., 1400., 1600.]),
#  <a list of 9 Text major ticklabel objects>)

# %%
sns.pairplot(data)

# %%
sns.pairplot(data, hue = "Segment")

# %%
sns.pairplot(data, hue = "Ship Mode")

# %%
state = data.groupby('State')[['Profit']].sum().plot.bar(figsize=(30,10))
plt.xticks(rotation =65)
plt.xlabel("State", fontsize=15)
plt.ylabel("Profit", fontsize=15)
plt.title("State wise Profit", fontsize=20)
plt.xticks(fontsize = 15, rotation =65)
plt.yticks(fontsize = 15)
# Out:
# (array([-40000., -20000.,      0.,  20000.,  40000.,  60000.,  80000.,
#         100000.]), <a list of 8 Text major ticklabel objects>)

# %%
state = data.groupby('Category')[['Sales']].sum().plot.bar(figsize=(10,10))
plt.xticks(rotation =65)
plt.ylabel("Sales", fontsize = 15)
plt.xlabel("Category", fontsize = 15)
plt.title("Sales in different categories", fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Sales in different categories')

# %% [markdown]
# **Here we can observe that Technology has more sales than furniture and at last office supplies.**

# %%
state = data.groupby('Sub-Category', sort = True)[['Sales']].sum()
state = state.sort_values(['Sales'], ascending = False)
state.plot.bar(color = ["magenta"], figsize=(20,10))

plt.xlabel("Sub-Categories", fontsize=15)
plt.ylabel("Sales", fontsize=15)
plt.xticks(rotation =65)
plt.title("Sales in different sub-categories", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Sales in different sub-categories')

# %% [markdown]
# **From this graph we can conclude that Phones has the highest sales then chairs and so on.**

# %%
state = data.groupby('Region')[['Sales']].sum()
state = state.sort_values(['Sales'], ascending = False)
state.plot.bar(color = ["indigo"], figsize=(10,10))

plt.xlabel("Region", fontsize=15)
plt.ylabel("Sales", fontsize=15)
plt.xticks(rotation =65)
plt.title("Sales in different Region", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Sales in different Region')

# %% [markdown]
# **This shows that west region has heighest sale and south region has lowest.**

# %%
state = data.groupby('Sub-Category', sort = True)[['Sales']].sum()
state.plot(kind='line', color = ["magenta"], figsize=(20,10))
plt.title("Sales",fontsize= 14)
plt.xlabel("Sub-Category", size = 14)
plt.ylabel("Sales ", size = 14)
plt.xticks(size = 14)
plt.yticks(size = 14)
# Out:
# (array([-50000.,      0.,  50000., 100000., 150000., 200000., 250000.,
#         300000., 350000.]), <a list of 9 Text major ticklabel objects>)

# %% [markdown]
# ***From above data analysis some conclusions we can drive are:***
#
#
# *   Standard Class ship mode is prefered more and  same day ship mode is preffered least.
# *   There is high demand for consumer segment and least demand for Home office segment.
# *   States like California and New-York has highest profit whereas Texas has least profit soe selling our products in these two states will benefit us more than any other states.
# *   Sub categories like phones, tables, chairs, binders has highest sales whereas fateners, labels, envelpoes etc has has the least sales so we need to focus and promote these categories more to increase there sales.
# *   West region has highest sales where as South region has lowest so by selling our products in western region will be benificial and we need to take some measures to increase sales in south region.
